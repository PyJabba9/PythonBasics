# %%
import datetime, time
from pathlib import Path

# %%
import logging
logfile = Path('C:/Users/***/Archive/Logs/Logfile.txt') # set to variable later
logging.basicConfig(filename=str(logfile),
                    filemode='a',
                    format='%(asctime)s,%(msecs)03d %(name)s %(levelname)s %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.DEBUG, force=True)

# %%
while True:
    logging.info("Running Timer loop")
    current_dateTime = datetime.datetime.today().strftime('%Y-%m-%d;%H:%M')
    print(f'Checking FTP on {current_dateTime}')
    last_refresh_time = current_dateTime # getting timestamp for specific data load try
    # %run WinSCP_downloader.ipynb 
    if status_w == True or status_m == True:
        last_load_datetime = datetime.datetime.today().strftime('%Y-%m-%d;%H:%M')
        # %run Main.ipynb # -if new data appeared - proceed with further processing into SQL and DQ stages
    else:
        print('no new files, no load appeared')
    time.sleep(1800) # waiting 30 min
